# %% [markdown]
# <a href="https://colab.research.google.com/github/ionikim/EEG_practice/blob/main/preprocessing/EEG_preprocessing_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mne hu-neuro-pipeline
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 82.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 7.8 MB/s eta 0:00:00
# ...

# %%
from mne import set_bipolar_reference
from mne.io import read_raw
from mne.preprocessing import ICA
from pipeline.datasets import get_erpcore

# %%
files_dict = get_erpcore('N170', participants='sub-004', path='data')
files_dict
# Out:
# ...
# {'log_files': ['/content/data/erpcore/N170/sub-004/eeg/sub-004_task-N170_events.tsv'],
#  'raw_files': ['/content/data/erpcore/N170/sub-004/eeg/sub-004_task-N170_eeg.set']}
